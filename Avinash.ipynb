# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("C:\\Users\\guntu\\Downloads\\region_hospital_icu_covid_data.csv")
data1
# Out:
#             date oh_region  icu_current_covid  icu_current_covid_vented  \
# 0     02-04-2020   CENTRAL                 51                        39
# 1     03-04-2020   CENTRAL                 57                        52
# 2     04-04-2020   CENTRAL                 65                        57
# 3     05-04-2020   CENTRAL                 65                        55
# 4     06-04-2020   CENTRAL                 73                        58
# ...          ...       ...                ...                       ...
# 2950  10-11-2021      WEST                 48                        30
# 2951  11-11-2021      WEST                 43                        26
# 2952  12-11-2021      WEST                 44                        26
# 2953  13-11-2021      WEST                 41                        27
# 2954  14-11-2021      WEST                 43                        28
#
#       hospitalizations  icu_crci_total  icu_crci_total_vented  \
# ...

# %%
data1.dtypes
# Out:
# date                        object
# oh_region                   object
# icu_current_covid            int64
# icu_current_covid_vented     int64
# hospitalizations             int64
# icu_crci_total               int64
# icu_crci_total_vented        int64
# icu_former_covid             int64
# icu_former_covid_vented      int64
# dtype: object

# %%
data1.shape
# Out:
# (2955, 9)

# %%
data1.head(5)
# Out:
#          date oh_region  icu_current_covid  icu_current_covid_vented  \
# 0  02-04-2020   CENTRAL                 51                        39
# 1  03-04-2020   CENTRAL                 57                        52
# 2  04-04-2020   CENTRAL                 65                        57
# 3  05-04-2020   CENTRAL                 65                        55
# 4  06-04-2020   CENTRAL                 73                        58
#
#    hospitalizations  icu_crci_total  icu_crci_total_vented  icu_former_covid  \
# 0               113               0                      0                 0
# 1               141               0                      0                 0
# 2               143               0                      0                 0
# 3               174               0                      0                 0
# 4               187               0                      0                 0
#
#    icu_former_covid_vented
# 0                        0
# 1                        0
# ...

# %%
data1.tail(5)
# Out:
#             date oh_region  icu_current_covid  icu_current_covid_vented  \
# 2950  10-11-2021      WEST                 48                        30
# 2951  11-11-2021      WEST                 43                        26
# 2952  12-11-2021      WEST                 44                        26
# 2953  13-11-2021      WEST                 41                        27
# 2954  14-11-2021      WEST                 43                        28
#
#       hospitalizations  icu_crci_total  icu_crci_total_vented  \
# 2950               107              56                     34
# 2951               107              56                     32
# 2952               118              56                     33
# 2953               114              55                     36
# 2954                84              57                     36
#
#       icu_former_covid  icu_former_covid_vented
# 2950                 8                        4
# 2951                13                        6
# ...

# %%
data1.info
# Out:
# <bound method DataFrame.info of             date oh_region  icu_current_covid  icu_current_covid_vented  \
# 0     02-04-2020   CENTRAL                 51                        39
# 1     03-04-2020   CENTRAL                 57                        52
# 2     04-04-2020   CENTRAL                 65                        57
# 3     05-04-2020   CENTRAL                 65                        55
# 4     06-04-2020   CENTRAL                 73                        58
# ...          ...       ...                ...                       ...
# 2950  10-11-2021      WEST                 48                        30
# 2951  11-11-2021      WEST                 43                        26
# 2952  12-11-2021      WEST                 44                        26
# 2953  13-11-2021      WEST                 41                        27
# 2954  14-11-2021      WEST                 43                        28
#
#       hospitalizations  icu_crci_total  icu_crci_total_vented  \
# ...

# %%
data1.describe(include='all')
# Out:
#               date oh_region  icu_current_covid  icu_current_covid_vented  \
# count         2955      2955        2955.000000               2955.000000
# unique         591         5                NaN                       NaN
# top     17-04-2020      WEST                NaN                       NaN
# freq             5       591                NaN                       NaN
# mean           NaN       NaN          43.228426                 29.473096
# std            NaN       NaN          48.969962                 34.981766
# min            NaN       NaN           0.000000                  0.000000
# 25%            NaN       NaN           7.000000                  4.000000
# 50%            NaN       NaN          26.000000                 17.000000
# 75%            NaN       NaN          61.000000                 42.000000
# max            NaN       NaN         278.000000                217.000000
#
#         hospitalizations  icu_crci_total  icu_crci_total_vented  \
# ...

# %%
data1.isnull().sum()
# Out:
# date                        0
# oh_region                   0
# icu_current_covid           0
# icu_current_covid_vented    0
# hospitalizations            0
# icu_crci_total              0
# icu_crci_total_vented       0
# icu_former_covid            0
# icu_former_covid_vented     0
# dtype: int64

# %%
data1.sum()
# Out:
# date                        02-04-202003-04-202004-04-202005-04-202006-04-...
# oh_region                   CENTRALCENTRALCENTRALCENTRALCENTRALCENTRALCENT...
# icu_current_covid                                                      127740
# icu_current_covid_vented                                                87093
# hospitalizations                                                       366093
# icu_crci_total                                                         137042
# icu_crci_total_vented                                                   91489
# icu_former_covid                                                        16210
# icu_former_covid_vented                                                  9810
# dtype: object

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data1.oh_region.unique()
# Out:
# array(['CENTRAL', 'EAST', 'NORTH', 'TORONTO', 'WEST'], dtype=object)

# %%
data1.boxplot(column=['hospitalizations'],by='oh_region')
title_boxplot = 'Box Plot to detect Outliers'
plt.title( title_boxplot )
plt.suptitle('') # that's what you're after
plt.show()

# %%
data1.oh_region.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of records by OH Region")
plt.ylabel("Number of Records")
plt.xlabel("OH Region")
# Out:
# Text(0.5, 0, 'OH Region')

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(data1['icu_current_covid_vented'], data1['icu_crci_total_vented'])
ax.set_xlabel("icu_current_covid_vented")
ax.set_ylabel("icu_crci_total_vented")
plt.show()
